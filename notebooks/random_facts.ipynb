# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# %load_ext autoreload
# %autoreload 2

from src.random_facts import load_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = load_data()
df
# Out:
#       placeId             placeName     category  value  \
# 0           0           Ganze Stadt  Stadtgebiet   91.9
# 1           1               Kreis 1  Stadtgebiet    1.8
# 2           2               Kreis 2  Stadtgebiet   11.1
# 3           3               Kreis 3  Stadtgebiet    8.7
# 4           4               Kreis 4  Stadtgebiet    2.9
# ...       ...                   ...          ...    ...
# 2157     1150              Oerlikon      Verkehr   14.0
# 2158     1190               Seebach      Verkehr    8.0
# 2159     1210               Saatlen      Verkehr    3.0
# 2160     1220  Schwamendingen-Mitte      Verkehr    5.0
# 2161     1230            Hirzenbach      Verkehr    3.0
#
#                            topic                  topic_slug
# 0     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 1     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 2     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 3     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 4     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# ...                          ...                         ...
# 2157          Mobility Standorte          Mobility Standorte
# 2158          Mobility Standorte          Mobility Standorte
# 2159          Mobility Standorte          Mobility Standorte
# 2160          Mobility Standorte          Mobility Standorte
# 2161          Mobility Standorte          Mobility Standorte
#
# [2162 rows x 6 columns]

# %%
df['topic_slug'].unique()
# Out:
# array(['Fläche in Quadratkilometer', 'Anteil der Waldfläche in %',
#        'Anteil der Gewässerfläche in %', 'Brunnen', 'Bäume',
#        'Schulen (Volksschule)', 'Freibäder',
#        'Fussball (städtische Anlagen)',
#        'Beachvolleyball (städtische Anlagen)',
#        'Wohnbevölkerung (Anzahl Personen)', 'Neugeborene pro Jahr',
#        'Todesfälle pro Jahr', 'Zuziehende (Anzahl Personen pro Jahr)',
#        'Wegziehende (Anzahl Personen pro Jahr)', 'Ausländeranteil in %',
#        'Häufigste ausländische Nationalität (Anzahl Personen)',
#        'Zweithäufigste ausländische Nationalität (Anzahl Personen)',
#        'Dritthäufigste ausländische Nationalität (Anzahl Personen)',
#        'Älteste Frau (Alter)', 'Ältester Mann (Alter)',
#        'Einpersonen-Haushalte (Anteil an allen Haushalten in %)',
#        'Haushalte mit Kindern (Anteil an allen Haushalten in %)',
#        'Kinderkrippen', 'Wohnungen',
#        'Neubauwohnungen der letzten fünf Jahre',
#        'Abgebrochene Wohnungen der letzten fünf Jahre',
#        'Durchschnittliche Wohnfläche (Quadratmeter pro Person)',
#        'Anzahl über 100-jährige Gebäude',
#        'Baujahr des ältesten Gebäudes (Adresse',
#        'Anzahl Stockwerke des höchsten Gebäudes (Adresse', 'Wohngebäude',
#        'Einfamilienhäuser', 'Tram- und Buswartehäuschen', 'Beschäftigte',
#        'Beschäftigte im 3. Sektor (Dienstleistungen) in %',
#        'Beschäftigte im 2. Sektor (Industrie) in %',
#        'Beschäftigte im 1. Sektor (Land- und Forstwirtschaft) in %',
#        'Arbeitslose', 'Arbeitslosenquote in %',
#        'Arztpraxen (Allgemeinmedizin und Fachärzte)', 'Zahnarztpraxen',
#        'Motorräder', 'Autos',
#        'Autos pro hundert Personen (18 Jährige und Ältere)',
#        'Zweiradabstellplätze', 'Mobility Standorte'], dtype=object)

# %%
df[df['topic_slug'] == 'Anzahl Stockwerke des höchsten Gebäudes (Adresse']
# Out:
#       placeId             placeName        category  value  \
# 1363        0           Ganze Stadt  Bauen & Wohnen   37.0
# 1364        1               Kreis 1  Bauen & Wohnen   15.0
# 1365        2               Kreis 2  Bauen & Wohnen   23.0
