# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# %load_ext autoreload
# %autoreload 2

from src.random_facts import load_data

# %%
df = load_data()
df
# Out:
#       placeId             placeName     category  value  \
# 0           0           Ganze Stadt  Stadtgebiet   91.9
# 1           1               Kreis 1  Stadtgebiet    1.8
# 2           2               Kreis 2  Stadtgebiet   11.1
# 3           3               Kreis 3  Stadtgebiet    8.7
# 4           4               Kreis 4  Stadtgebiet    2.9
# ...       ...                   ...          ...    ...
# 2157     1150              Oerlikon      Verkehr   14.0
# 2158     1190               Seebach      Verkehr    8.0
# 2159     1210               Saatlen      Verkehr    3.0
# 2160     1220  Schwamendingen-Mitte      Verkehr    5.0
# 2161     1230            Hirzenbach      Verkehr    3.0
#
#                            topic                  topic_slug
# 0     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 1     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 2     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 3     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# 4     Fläche in Quadratkilometer  Fläche in Quadratkilometer
# ...                          ...                         ...
# 2157          Mobility Standorte          Mobility Standorte
# 2158          Mobility Standorte          Mobility Standorte
# 2159          Mobility Standorte          Mobility Standorte
# 2160          Mobility Standorte          Mobility Standorte
# 2161          Mobility Standorte          Mobility Standorte
#
# [2162 rows x 6 columns]

# %%
df['topic_slug'].unique()
# Out:
# array(['Fläche in Quadratkilometer', 'Anteil der Waldfläche in %',
#        'Anteil der Gewässerfläche in %', 'Brunnen', 'Bäume',
#        'Schulen (Volksschule)', 'Freibäder',
#        'Fussball (städtische Anlagen)',
#        'Beachvolleyball (städtische Anlagen)',
#        'Wohnbevölkerung (Anzahl Personen)', 'Neugeborene pro Jahr',
#        'Todesfälle pro Jahr', 'Zuziehende (Anzahl Personen pro Jahr)',
#        'Wegziehende (Anzahl Personen pro Jahr)', 'Ausländeranteil in %',
#        'Häufigste ausländische Nationalität (Anzahl Personen)',
#        'Zweithäufigste ausländische Nationalität (Anzahl Personen)',
#        'Dritthäufigste ausländische Nationalität (Anzahl Personen)',
#        'Älteste Frau (Alter)', 'Ältester Mann (Alter)',
#        'Einpersonen-Haushalte (Anteil an allen Haushalten in %)',
#        'Haushalte mit Kindern (Anteil an allen Haushalten in %)',
#        'Kinderkrippen', 'Wohnungen',
#        'Neubauwohnungen der letzten fünf Jahre',
#        'Abgebrochene Wohnungen der letzten fünf Jahre',
#        'Durchschnittliche Wohnfläche (Quadratmeter pro Person)',
#        'Anzahl über 100-jährige Gebäude',
#        'Baujahr des ältesten Gebäudes (Adresse',
#        'Anzahl Stockwerke des höchsten Gebäudes (Adresse', 'Wohngebäude',
#        'Einfamilienhäuser', 'Tram- und Buswartehäuschen', 'Beschäftigte',
#        'Beschäftigte im 3. Sektor (Dienstleistungen) in %',
#        'Beschäftigte im 2. Sektor (Industrie) in %',
#        'Beschäftigte im 1. Sektor (Land- und Forstwirtschaft) in %',
#        'Arbeitslose', 'Arbeitslosenquote in %',
#        'Arztpraxen (Allgemeinmedizin und Fachärzte)', 'Zahnarztpraxen',
#        'Motorräder', 'Autos',
#        'Autos pro hundert Personen (18 Jährige und Ältere)',
#        'Zweiradabstellplätze', 'Mobility Standorte'], dtype=object)

# %%
df[df['topic_slug'] == 'Arztpraxen (Allgemeinmedizin und Fachärzte)']
# Out:
#       placeId             placeName             category   value  \
# 1833        0           Ganze Stadt  Wirtschaft & Arbeit  2130.0
# 1834        1               Kreis 1  Wirtschaft & Arbeit   260.0
# 1835        2               Kreis 2  Wirtschaft & Arbeit   222.0
# 1836        3               Kreis 3  Wirtschaft & Arbeit    95.0
# 1837        4               Kreis 4  Wirtschaft & Arbeit    95.0
# 1838        5               Kreis 5  Wirtschaft & Arbeit    46.0
# 1839        6               Kreis 6  Wirtschaft & Arbeit   245.0
# 1840        7               Kreis 7  Wirtschaft & Arbeit   472.0
# 1841        8               Kreis 8  Wirtschaft & Arbeit   413.0
# 1842        9               Kreis 9  Wirtschaft & Arbeit    80.0
# 1843       10              Kreis 10  Wirtschaft & Arbeit    52.0
# 1844       11              Kreis 11  Wirtschaft & Arbeit   123.0
# 1845       12              Kreis 12  Wirtschaft & Arbeit    27.0
# 1846      110               Rathaus  Wirtschaft & Arbeit    72.0
# 1847      120           Hochschulen  Wirtschaft & Arbeit    89.0
# 1848      130             Lindenhof  Wirtschaft & Arbeit    36.0
# 1849      140                  City  Wirtschaft & Arbeit    63.0
# 1850      210           Wollishofen  Wirtschaft & Arbeit    64.0
# 1851      230              Leimbach  Wirtschaft & Arbeit     5.0
# 1852      240                  Enge  Wirtschaft & Arbeit   153.0
# 1853      310          Alt-Wiedikon  Wirtschaft & Arbeit    30.0
# 1854      330           Friesenberg  Wirtschaft & Arbeit    26.0
# 1855      340              Sihlfeld  Wirtschaft & Arbeit    39.0
# 1856      410                  Werd  Wirtschaft & Arbeit    45.0
# 1857      420           Langstrasse  Wirtschaft & Arbeit    25.0
# 1858      440                  Hard  Wirtschaft & Arbeit    25.0
# 1859      510         Gewerbeschule  Wirtschaft & Arbeit    21.0
# 1860      520           Escher Wyss  Wirtschaft & Arbeit    25.0
# 1861      610           Unterstrass  Wirtschaft & Arbeit   145.0
# 1862      630            Oberstrass  Wirtschaft & Arbeit   100.0
# 1863      710              Fluntern  Wirtschaft & Arbeit   177.0
# 1864      720             Hottingen  Wirtschaft & Arbeit   218.0
# 1865      730            Hirslanden  Wirtschaft & Arbeit    55.0
# 1866      740               Witikon  Wirtschaft & Arbeit    22.0
# 1867      810               Seefeld  Wirtschaft & Arbeit   135.0
# 1868      820             Mühlebach  Wirtschaft & Arbeit    65.0
# 1869      830               Weinegg  Wirtschaft & Arbeit   213.0
# 1870      910           Albisrieden  Wirtschaft & Arbeit    22.0
# 1871      920            Altstetten  Wirtschaft & Arbeit    58.0
# 1872     1010                 Höngg  Wirtschaft & Arbeit    28.0
# 1873     1020             Wipkingen  Wirtschaft & Arbeit    24.0
# 1874     1110             Affoltern  Wirtschaft & Arbeit    14.0
# 1875     1150              Oerlikon  Wirtschaft & Arbeit    88.0
# 1876     1190               Seebach  Wirtschaft & Arbeit    21.0
# 1877     1210               Saatlen  Wirtschaft & Arbeit     8.0
# 1878     1220  Schwamendingen-Mitte  Wirtschaft & Arbeit    15.0
# 1879     1230            Hirzenbach  Wirtschaft & Arbeit     4.0
#
#                                             topic  \
# 1833  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1834  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1835  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1836  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1837  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1838  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1839  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1840  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1841  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1842  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1843  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1844  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1845  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1846  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1847  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1848  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1849  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1850  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1851  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1852  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1853  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1854  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1855  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1856  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1857  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1858  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1859  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1860  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1861  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1862  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1863  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1864  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1865  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1866  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1867  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1868  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1869  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1870  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1871  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1872  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1873  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1874  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1875  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1876  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1877  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1878  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1879  Arztpraxen (Allgemeinmedizin und Fachärzte)
#
#                                        topic_slug
# 1833  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1834  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1835  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1836  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1837  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1838  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1839  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1840  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1841  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1842  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1843  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1844  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1845  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1846  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1847  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1848  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1849  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1850  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1851  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1852  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1853  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1854  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1855  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1856  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1857  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1858  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1859  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1860  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1861  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1862  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1863  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1864  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1865  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1866  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1867  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1868  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1869  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1870  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1871  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1872  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1873  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1874  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1875  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1876  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1877  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1878  Arztpraxen (Allgemeinmedizin und Fachärzte)
# 1879  Arztpraxen (Allgemeinmedizin und Fachärzte)
